# %% [markdown]
# ## ***`Import the required Libraries`***

# %%
# !pip install spotipy
# Out:
# ...
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# ...
#
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
#    ------------- -------------------------- 1/3 [redis]
# ...

# %%
! pip install pandas
# Out:
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------- -------------------------- 3.9/11.3 MB 21.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.3 MB 16.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.3 MB 13.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.9 MB 18.2 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.9 MB 14.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.9 MB 14.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 14.2 MB/s eta 0:00:01
# ...

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.1 MB 19.6 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 12.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 12.5 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 25.6 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------- ------------------------ 2.6/7.0 MB 21.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## ***`Extract Data `***

# %%
# spotify.py

from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pandas as pd
import matplotlib.pyplot as plt
import re

# Set up Client Credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='ca296ce7a51c4a089a501c729fba50dc',  # Replace with your Client ID
    client_secret='4bb7e49bc3f5476fb40726b893251ea7'  # Replace with your Client Secret
))


# Full track URL (example: Shape of You by Ed Sheeran)
track_url = "https://open.spotify.com/track/0MTdYgTZ25sLCO6kVnDoje"

# Extract track ID directly from URL using regex
track_id = re.search(r'track/([a-zA-Z0-9]+)', track_url).group(1)

# Fetch track details
track = sp.track(track_id)
print(track)
# Extract metadata
track_data = {
    'Track Name': track['name'],
    'Artist': track['artists'][0]['name'],
    'Album': track['album']['name'],
    'Popularity': track['popularity'],
    'Duration (minutes)': track['duration_ms'] / 60000
}

# Display metadata
print(f"\nTrack Name: {track_data['Track Name']}")
print(f"Artist: {track_data['Artist']}")
print(f"Album: {track_data['Album']}")
print(f"Popularity: {track_data['Popularity']}")
print(f"Duration: {track_data['Duration (minutes)']:.2f} minutes")

# Convert metadata to DataFrame
df = pd.DataFrame([track_data])
print("\nTrack Data as DataFrame:")
print(df)

# Save metadata to CSV
df.to_csv('spotify_think_inde.csv', index=False)

# Visualize track data
features = ['Popularity', 'Duration (minutes)']
values = [track_data['Popularity'], track_data['Duration (minutes)']]

plt.figure(figsize=(8, 5))
plt.bar(features, values, color='skyblue', edgecolor='black')
plt.title(f"Track Metadata for '{track_data['Track Name']}'")
plt.ylabel('Value')
plt.show()
# Out:
# {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5jJrJU7VVmxQQLcLAmmxXc'}, 'href': 'https://api.spotify.com/v1/artists/5jJrJU7VVmxQQLcLAmmxXc', 'id': '5jJrJU7VVmxQQLcLAmmxXc', 'name': 'Sai Abhyankkar', 'type': 'artist', 'uri': 'spotify:artist:5jJrJU7VVmxQQLcLAmmxXc'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/139FRgoVcJ82jogPttiWcc'}, 'href': 'https://api.spotify.com/v1/artists/139FRgoVcJ82jogPttiWcc', 'id': '139FRgoVcJ82jogPttiWcc', 'name': 'Sai Smriti', 'type': 'artist', 'uri': 'spotify:artist:139FRgoVcJ82jogPttiWcc'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 
# ...

# %% [markdown]
# ## ***`Extract And Insert to MySQL`***

# %%
# spotify_mysql.py


import re
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector

# Set up Spotify API credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='ca296ce7a51c4a089a501c729fba50dc',  # Replace with your Client ID
    client_secret='4bb7e49bc3f5476fb40726b893251ea7'  # Replace with your Client Secret
))

# MySQL Database Connection
db_config = {
    'host': 'localhost',           # Change to your MySQL host
    'user': 'root',       # Replace with your MySQL username
    'password': 'root',   # Replace with your MySQL password
    'database': 'spotify'       # Replace with your database name
}

# Connect to the database
connection = mysql.connector.connect(**db_config)
cursor = connection.cursor()

# Full track URL (example: Shape of You by Ed Sheeran)
track_url = "https://open.spotify.com/track/0MTdYgTZ25sLCO6kVnDoje"

# Extract track ID directly from URL
track_id = re.search(r'track/([a-zA-Z0-9]+)', track_url).group(1)

# Fetch track details
track = sp.track(track_id)

# Extract metadata
track_data = {
    'Track Name': track['name'],
    'Artist': track['artists'][0]['name'],
    'Album': track['album']['name'],
    'Popularity': track['popularity'],
    'Duration (minutes)': track['duration_ms'] / 60000
}

# Insert data into MySQL
insert_query = """
INSERT INTO spotify_tracks (track_name, artist, album, popularity, duration_minutes)
VALUES (%s, %s, %s, %s, %s)
"""
cursor.execute(insert_query, (
    track_data['Track Name'],
    track_data['Artist'],
    track_data['Album'],
    track_data['Popularity'],
    track_data['Duration (minutes)']
))
connection.commit()

print(f"Track '{track_data['Track Name']}' by {track_data['Artist']} inserted into the database.")

# Close the connection
cursor.close()
connection.close()

# %% [markdown]
# ## ***`Filter the Loaded Data using SQL`***

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/

# %%
# %%sql
# create database spotify;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# []

# %%
# %%sql
# use spotify;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS spotify.spotify_tracks (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     track_name VARCHAR(255),
#     artist VARCHAR(255),
#     album VARCHAR(255),
#     popularity INT,
#     duration_minutes FLOAT
# )
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
#
# # BEFORE INSERT
# select * from spotify.spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# # AFTER INSERT
# select * from spotify.spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(1, 'Aasa Kooda - From "Think Indie"', 'Sai Abhyankkar', 'Aasa Kooda (From "Think Indie")', 77, 3.59183)]

# %%
# %%sql
#
# truncate table spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %% [markdown]
# ## ***`ETA_Multiple_Tracks`***

# %%
# spotify_mysql_urls.py

import re
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import mysql.connector

# Set up Spotify API credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='ca296ce7a51c4a089a501c729fba50dc',  # Replace with your Client ID
    client_secret='4bb7e49bc3f5476fb40726b893251ea7'  # Replace with your Client Secret
))

# MySQL Database Connection
db_config = {
    'host': 'localhost',           # Change to your MySQL host
    'user': 'root',       # Replace with your MySQL username
    'password': 'root',   # Replace with your MySQL password
    'database': 'spotify'       # Replace with your database name
}

# Connect to the database
connection = mysql.connector.connect(**db_config)
cursor = connection.cursor()

# Read track URLs from file
file_path = "track_urls.txt"
with open(file_path, 'r') as file:
    track_urls = file.readlines()

# Process each URL
for track_url in track_urls:
    track_url = track_url.strip()  # Remove any leading/trailing whitespace
    try:
        # Extract track ID from URL
        track_id = re.search(r'track/([a-zA-Z0-9]+)', track_url).group(1)

        # Fetch track details from Spotify API
        track = sp.track(track_id)

        # Extract metadata
        track_data = {
            'Track Name': track['name'],
            'Artist': track['artists'][0]['name'],
            'Album': track['album']['name'],
            'Popularity': track['popularity'],
            'Duration (minutes)': track['duration_ms'] / 60000
        }

        # Insert data into MySQL
        insert_query = """
        INSERT INTO spotify_tracks (track_name, artist, album, popularity, duration_minutes)
        VALUES (%s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            track_data['Track Name'],
            track_data['Artist'],
            track_data['Album'],
            track_data['Popularity'],
            track_data['Duration (minutes)']
        ))
        connection.commit()

        print(f"Inserted: {track_data['Track Name']} by {track_data['Artist']}")

    except Exception as e:
        print(f"Error processing URL: {track_url}, Error: {e}")

# Close the connection
cursor.close()
connection.close()

print("All tracks have been processed and inserted into the database.")
# Out:
# Inserted: Aasa Kooda - From "Think Indie" by Sai Abhyankkar
# Inserted: Golden Sparrow (From "Nilavuku En Mel Ennadi Kobam") by G. V. Prakash
# Inserted: Dheema (From "Love Insurance Kompany") by Anirudh Ravichander
# Inserted: Unnai Kaanadhu Naan by Shankar-Ehsaan-Loy
# Inserted: Vizhi Moodi by Karthik
# Inserted: Kannamma - From "Ispade Rajavum Idhaya Raniyum" by Sam C.S.
# Inserted: Aaruyire by A.R. Rahman
# Inserted: Kadhal Aasai by Yuvan Shankar Raja
# Inserted: Venmegam by Yuvan Shankar Raja
# Inserted: Kaattrae En Vaasal - Wind by Unnikrishnan
# All tracks have been processed and inserted into the database.

# %%
# %%sql
#
# select * from spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 10 rows affected.
# [(1, 'Aasa Kooda - From "Think Indie"', 'Sai Abhyankkar', 'Aasa Kooda (From "Think Indie")', 77, 3.59183),
#  (2, 'Golden Sparrow (From "Nilavuku En Mel Ennadi Kobam")', 'G. V. Prakash', 'Nilavuku En Mel Ennadi Kobam (Original Motion Picture Soundtrack)', 62, 3.84),
#  (3, 'Dheema (From "Love Insurance Kompany")', 'Anirudh Ravichander', 'Dheema (From "Love Insurance Kompany")', 66, 3.91837),
#  (4, 'Unnai Kaanadhu Naan', 'Shankar-Ehsaan-Loy', 'Vishwaroopam (Tamil) [Original Motion Picture Soundtrack]', 63, 5.61888),
#  (5, 'Vizhi Moodi', 'Karthik', 'Ayan', 65, 5.53777),
#  (6, 'Kannamma - From "Ispade Rajavum Idhaya Raniyum"', 'Sam C.S.', 'Kannamma (From "Ispade Rajavum Idhaya Raniyum")', 69, 4.28242),
#  (7, 'Aaruyire', 'A.R. Rahman', 'Guru (Original Motion Picture Soundtrack)', 70, 5.14643),
#  (8, 'Kadhal Aasai', 'Yuvan Shankar Raja', 'Anjaan (Original Motion Picture Soundtrack)', 65, 5.0625),
# ...

# %%
# %%sql
# # retireve the first popularity
# SELECT track_name, artist, album, popularity
# FROM spotify_tracks
# ORDER BY popularity DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('Aasa Kooda - From "Think Indie"', 'Sai Abhyankkar', 'Aasa Kooda (From "Think Indie")', 77)]

# %%
# %%sql
#
# SELECT track_name, artist, duration_minutes
# FROM spotify_tracks
# WHERE duration_minutes > 4.0;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 7 rows affected.
# [('Unnai Kaanadhu Naan', 'Shankar-Ehsaan-Loy', 5.61888),
#  ('Vizhi Moodi', 'Karthik', 5.53777),
#  ('Kannamma - From "Ispade Rajavum Idhaya Raniyum"', 'Sam C.S.', 4.28242),
#  ('Aaruyire', 'A.R. Rahman', 5.14643),
#  ('Kadhal Aasai', 'Yuvan Shankar Raja', 5.0625),
#  ('Venmegam', 'Yuvan Shankar Raja', 4.58088),
#  ('Kaattrae En Vaasal - Wind', 'Unnikrishnan', 6.30933)]

# %%
# %%sql
# SELECT
#     CASE
#         WHEN popularity >= 5 THEN 'Very Popular'
#         WHEN popularity >= 4 THEN 'Popular'
#     END AS popularity_range,
#     COUNT(*) AS track_count
# FROM spotify_tracks
# GROUP BY popularity_range;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('Very Popular', 10)]

# %%
# spotify_mysql_urls.py

import re
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import mysql.connector

# Set up Spotify API credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='ca296ce7a51c4a089a501c729fba50dc',  # Replace with your Client ID
    client_secret='4bb7e49bc3f5476fb40726b893251ea7'  # Replace with your Client Secret
))

# MySQL Database Connection
db_config = {
    'host': 'localhost',           # Change to your MySQL host
    'user': 'root',       # Replace with your MySQL username
    'password': 'root',   # Replace with your MySQL password
    'database': 'spotify'       # Replace with your database name
}

# Connect to the database
connection = mysql.connector.connect(**db_config)
cursor = connection.cursor()

# Read track URLs from file
file_path = "gowtham_tracks.txt"
with open(file_path, 'r') as file:
    track_urls = file.readlines()

# Process each URL
for track_url in track_urls:
    track_url = track_url.strip()  # Remove any leading/trailing whitespace
    try:
        # Extract track ID from URL
        track_id = re.search(r'track/([a-zA-Z0-9]+)', track_url).group(1)

        # Fetch track details from Spotify API
        track = sp.track(track_id)

        # Extract metadata
        track_data = {
            'Track Name': track['name'],
            'Artist': track['artists'][0]['name'],
            'Album': track['album']['name'],
            'Popularity': track['popularity'],
            'Duration (minutes)': track['duration_ms'] / 60000
        }

        # Insert data into MySQL
        insert_query = """
        INSERT INTO spotify_tracks1 (track_name, artist, album, popularity, duration_minutes)
        VALUES (%s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            track_data['Track Name'],
            track_data['Artist'],
            track_data['Album'],
            track_data['Popularity'],
            track_data['Duration (minutes)']
        ))
        connection.commit()

        print(f"Inserted: {track_data['Track Name']} by {track_data['Artist']}")

    except Exception as e:
        print(f"Error processing URL: {track_url}, Error: {e}")

# Close the connection
cursor.close()
connection.close()

print("All tracks have been processed and inserted into the database.")
# Out:
# Inserted: Mr. Brightside by The Killers
# Inserted: Time is Running Out by Muse
# Inserted: Uprising by Muse
# Inserted: Despacito by Luis Fonsi
# Inserted: Mr. Brightside by The Killers
# Inserted: Lover by Taylor Swift
# Inserted: Shape of You by Ed Sheeran
# Inserted: Every Breath You Take by The Police
# Inserted: Prelude for Piano No. 11 in F-Sharp Minor by Eduard Abramyan
# All tracks have been processed and inserted into the database.

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS spotify.spotify_tracks1 (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     track_name VARCHAR(255),
#     artist VARCHAR(255),
#     album VARCHAR(255),
#     popularity INT,
#     duration_minutes FLOAT
# )
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# select * from spotify_tracks1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 9 rows affected.
# [(1, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 65, 3.70333),
#  (2, 'Time is Running Out', 'Muse', 'Absolution', 8, 3.95065),
#  (3, 'Uprising', 'Muse', 'The Resistance', 80, 5.08067),
#  (4, 'Despacito', 'Luis Fonsi', 'VIDA', 84, 3.82267),
#  (5, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 7, 3.70125),
#  (6, 'Lover', 'Taylor Swift', 'Lover', 86, 3.68843),
#  (7, 'Shape of You', 'Ed Sheeran', '÷ (Deluxe)', 91, 3.8952),
#  (8, 'Every Breath You Take', 'The Police', 'Synchronicity (Remastered 2003)', 92, 4.232),
#  (9, 'Prelude for Piano No. 11 in F-Sharp Minor', 'Eduard Abramyan', 'Abramyan: Preludes – Rachmaninoff: Sonata No. 2 in B-Flat Minor, Op. 36 – Babadjanyan: Capriccio, Improvisation, Folksong, Elegy, Poem', 26, 4.13822)]

# %%
# %%sql
# # retireve the first popularity
# SELECT track_name, artist, album, popularity
# FROM spotify_tracks
# ORDER BY popularity DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('Aasa Kooda - From "Think Indie"', 'Sai Abhyankkar', 'Aasa Kooda (From "Think Indie")', 77)]

# %%
# %%sql
# SELECT
#     CASE
#         WHEN popularity >= 80 THEN 'Very Popular'
#         WHEN popularity >=50 THEN 'Popular'
#         ELSE 'Less Popular'
#     END AS popularity_range,
#     COUNT(*) AS track_count
# FROM spotify_tracks1
# GROUP BY popularity_range;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [('Popular', 1), ('Less Popular', 3), ('Very Popular', 5)]
